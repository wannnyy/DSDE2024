# %%
import pandas as pd

# %%
# %pwd
# Out:
# 'c:\\Users\\tonwa\\OneDrive\\Documents\\DSDE2024\\grader\\assignment spatial and network analysis_6808466ba2e9e'

# %%
file = "airbnb_listings.csv"

# %%
df = pd.read_csv(file)

# %%
df
# Out:
#                         id                                            name  \
# 0                    27934                 Nice room with superb city view
# 1                    35780  Spacious one bedroom at The Kris Condo Bldg. 3
# 2                    48736                 Condo with Chaopraya River View
# 3                    55681                   Sathorn Terrace Apartment(61)
# 4                    55686    Comfy bedroom near River pier & BTS  Taksin.
# ...                    ...                                             ...
# 13566  1182978570804026627                 Lovely Local Life Near Wat Arun
# 13567  1183752031453100447                          【海天盛筵3】七间卧室市中心豪华泳池独栋别墅
# 13568  1183797228974724657                            【海天盛宴4】市中心七间卧室独栋泳池别墅
# 13569  1184458295770890723               Riverview | near icon  &asiatique
# 13570  1184995457662027445                Entire Townhouse 10 mins to Siam
#
#          host_id host_name neighbourhood   latitude   longitude  \
# ...

# %%
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood', 'latitude',
#        'longitude', 'room_type', 'price', 'minimum_nights',
#        'number_of_reviews', 'last_review', 'reviews_per_month',
#        'calculated_host_listings_count', 'availability_365',
#        'number_of_reviews_ltm'],
#       dtype='object')
